# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '78dad28c-5d45-470b-8f79-3f9175701d16',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-01-17T17:53:26.618Z', 'error_code': 0, 'error_message': None, 'elapsed': 13, 'credit_count': 1, 'notice': None, 'total_count': 8738}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10745, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19600900, 'total_supply': 19600900, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-01-17T17:52:00.000Z', 'quote': {'USD': {'price': 42373.95326594795, 'volume_24h': 21552865055.670914, 'volume_change_24h': -13.3443, 'percent_change_1h': 0.23326201, 'percent_change_24h': -1.61439074, 'percent_change_7d': -8.19893545, 'percent_change_30d': 1.8761805, 'percent_change_60d': 15.63841971, 'percent_change_90d': 48.3896586, 'market_cap': 830567620570.5192, 'market_cap_dominance': 49.6617, 'fully_diluted_market_cap': 889853018584.91, 'tvl': None, 'last_updated': '2024-01-17T17:52:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 8261, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120179738.31651795, 'total_supply': 120179738.31651795, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-01-17T17:52:00.000Z', 'quote': {'USD': {'price': 2530.998088613159, 'volume_24h': 11010601298.69393, 'volume_change_24h': 7.533, 'percent_change_1h': 0.08642739, 'percent_change_24h': -1.34093761, 'percent_change_7d': 4.02327202, 'percent_change_30d': 16.59867718, 'percent_change_60d': 28.69561919, 'percent_change_90d': 62.08215488, 'market_cap': 304174687969.13654, 'market_cap_dominance': 18.1874, 'fully_diluted_market_cap': 304174687969.14, 'tvl': None, 'last_updated': '2024-01-17T17:52:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 71910, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 95184775480.94475, 'total_supply': 98601637401.4351, 'platform ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10745
# 1    1027     Ethereum    ETH      ethereum              8261
# 2     825  Tether USDt   USDT        tether             71910
# 3    1839          BNB    BNB           bnb              2017
# 4    5426       Solana    SOL        solana               616
# 5      52          XRP    XRP           xrp              1206
# 6    3408         USDC   USDC      usd-coin             16235
# 7    2010      Cardano    ADA       cardano              1032
# 8    5805    Avalanche   AVAX     avalanche               640
# 9      74     Dogecoin   DOGE      dogecoin               875
# 10   1958         TRON    TRX          tron               903
# 11   6636     Polkadot    DOT  polkadot-new               666
# 12   1975    Chainlink   LINK     chainlink              1573
# 13  11419      Toncoin    TON       toncoin               189
# 14   3890      Polygon  MATIC       polygon              1246
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-07-13T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-08-19T00:00:00.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2021-08-26T13:40:22.000Z
# 14  2019-04-28T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 7   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 8   [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 9   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 10  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 11  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 12  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
# 13  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 14  [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.960090e+07  1.960090e+07            False       NaN         1
# 1         1.201797e+08  1.201797e+08             True       NaN         2
# 2         9.518478e+10  9.860164e+10             True       NaN         3
# 3         1.495493e+08  1.495493e+08            False       NaN         4
# 4         4.328108e+08  5.673964e+08             True       NaN         5
# 5         5.426682e+10  9.998801e+10            False       NaN         6
# 6         2.547746e+10  2.547746e+10            False       NaN         7
# 7         3.539515e+10  3.654270e+10            False       NaN         8
# 8         3.666635e+08  4.346964e+08            False       NaN         9
# 9         1.426920e+11  1.426920e+11             True       NaN        10
# 10        8.821614e+10  8.821620e+10             True       NaN        11
# 11        1.268568e+09  1.400829e+09             True       NaN        12
# 12        5.681000e+08  1.000000e+09            False       NaN        13
# 13        3.456870e+09  5.101314e+09             True       NaN        14
# 14        9.570276e+09  1.000000e+10            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      7.165966e+10              7.728977e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                      3.414167e+09              7.830907e+09      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-01-17T17:52:00.000Z     42373.953266          2.155287e+10
# 1   2024-01-17T17:52:00.000Z      2530.998089          1.101060e+10
# 2   2024-01-17T17:51:00.000Z         0.999126          4.029396e+10
# 3   2024-01-17T17:51:00.000Z       310.468046          1.201964e+09
# 4   2024-01-17T17:52:00.000Z        99.009844          2.847682e+09
# 5   2024-01-17T17:52:00.000Z         0.566516          8.788794e+08
# 6   2024-01-17T17:52:00.000Z         1.000041          5.247026e+09
# 7   2024-01-17T17:51:00.000Z         0.527236          3.088395e+08
# 8   2024-01-17T17:51:00.000Z        35.634974          5.369018e+08
# 9   2024-01-17T17:52:00.000Z         0.080085          2.739293e+08
# 10  2024-01-17T17:51:00.000Z         0.107857          2.213464e+08
# 11  2024-01-17T17:52:00.000Z         7.329891          1.922083e+08
# 12  2024-01-17T17:51:00.000Z        15.705428          7.553683e+08
# 13  2024-01-17T17:52:00.000Z         2.293651          5.913798e+07
# 14  2024-01-17T17:51:00.000Z         0.823301          3.323568e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -13.3443                     0.233262
# 1                        7.5330                     0.086427
# 2                       -8.5626                     0.012260
# 3                       -2.6600                    -0.235448
# 4                       51.5447                     0.023654
# 5                       -9.1092                    -0.144119
# 6                        0.8548                    -0.009499
# 7                       -5.3079                     0.167047
# 8                       13.2526                     0.209783
# 9                      -17.4363                    -0.042834
# 10                     -37.5728                    -0.004333
# 11                       0.7394                    -0.189460
# 12                      85.8751                    -1.208310
# 13                     -10.4074                    -0.205220
# 14                      11.1954                    -1.371596
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -1.614391                    -8.198935
# 1                      -1.340938                     4.023272
# 2                      -0.055694                    -0.131717
# 3                      -2.062388                     4.885849
# 4                       2.008787                     3.156461
# 5                      -1.925279                    -0.451834
# 6                      -0.004948                    -0.049718
# 7                      -2.631608                     3.888681
# 8                       0.236596                     0.875582
# 9                      -1.450144                     2.134109
# 10                     -0.358179                     3.278832
# 11                     -1.782822                     2.834396
# 12                      4.285481                    10.710169
# 13                     -5.539493                     3.800589
# 14                     -2.623644                    -2.524567
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       1.876181                     15.638420
# 1                      16.598677                     28.695619
# 2                      -0.049246                     -0.135787
# 3                      30.130111                     27.064993
# 4                      37.748828                     69.946253
# 5                      -5.682882                     -7.149862
# 6                      -0.017099                     -0.005379
# 7                      -8.008772                     42.097250
# 8                      -9.955926                     61.771257
# 9                     -11.146296                     -0.214288
# 10                      8.106912                      4.952844
# 11                      9.741222                     39.360970
# 12                     10.626538                     14.980932
# 13                      9.054970                     -1.880904
# 14                      5.675142                     -0.005748
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      48.389659          8.305676e+11
# 1                      62.082155          3.041747e+11
# 2                      -0.131370          9.510154e+10
# 3                      47.476673          4.643027e+10
# 4                     298.492296          4.285253e+10
# 5                      16.529189          3.074300e+10
# 6                      -0.017796          2.547851e+10
# 7                     116.269438          1.866160e+10
# 8                     297.601122          1.306604e+10
# 9                      37.110148          1.142743e+10
# 10                     20.331957          9.514704e+09
# 11                    102.368719          9.298465e+09
# 12                    113.672774          8.922253e+09
# 13                     10.048791          7.928854e+09
# 14                     60.563642          7.879222e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          49.6617                        8.898530e+11
# 1                          18.1874                        3.041747e+11
# 2                           5.6878                        9.851542e+10
# 3                           2.7762                        4.643027e+10
# 4                           2.5629                        5.617783e+10
# 5                           1.8401                        5.665155e+10
# 6                           1.5250                        2.547851e+10
# 7                           1.1161                        2.372562e+10
# 8                           0.7814                        2.565718e+10
# 9                           0.6833                        1.142743e+10
# 10                          0.5695                        9.514711e+09
# 11                          0.5560                        1.026792e+10
# 12                          0.5336                        1.570543e+10
# 13                          0.4742                        1.170063e+10
# 14                          0.4712                        8.233014e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-01-17T17:52:00.000Z          NaN           NaN
# 1           None  2024-01-17T17:52:00.000Z          NaN           NaN
# 2           None  2024-01-17T17:51:00.000Z       1027.0      Ethereum
# 3           None  2024-01-17T17:51:00.000Z          NaN           NaN
# 4           None  2024-01-17T17:52:00.000Z          NaN           NaN
# 5           None  2024-01-17T17:52:00.000Z          NaN           NaN
# 6           None  2024-01-17T17:52:00.000Z       1027.0      Ethereum
# 7           None  2024-01-17T17:51:00.000Z          NaN           NaN
# 8           None  2024-01-17T17:51:00.000Z          NaN           NaN
# 9           None  2024-01-17T17:52:00.000Z          NaN           NaN
# 10          None  2024-01-17T17:51:00.000Z          NaN           NaN
# 11          None  2024-01-17T17:52:00.000Z          NaN           NaN
# 12          None  2024-01-17T17:51:00.000Z       1027.0      Ethereum
# 13          None  2024-01-17T17:52:00.000Z          NaN           NaN
# 14          None  2024-01-17T17:51:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2024-01-17 18:53:25.774811
# 1  2024-01-17 18:53:25.774811
# 2  2024-01-17 18:53:25.774811
# 3  2024-01-17 18:53:25.774811
# 4  2024-01-17 18:53:25.774811
# 5  2024-01-17 18:53:25.774811
# 6  2024-01-17 18:53:25.774811
# 7  2024-01-17 18:53:25.774811
# 8  2024-01-17 18:53:25.774811
# 9  2024-01-17 18:53:25.774811
# 10 2024-01-17 18:53:25.774811
# 11 2024-01-17 18:53:25.774811
# 12 2024-01-17 18:53:25.774811
# 13 2024-01-17 18:53:25.774811
# 14 2024-01-17 18:53:25.774811

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',

        'X-CMC_PRO_API_KEY': '78dad28c-5d45-470b-8f79-3f9175701d16',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    #df2 = pd.json_normalize(data['data'])
    #df2['Timestamp'] = pd.to_datetime('now')
    #df = df.append(df2)


    # Use this if you want to create a csv and append data to it
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'C:\Users\mario\CSV de estudios\CryptoAPI.csv'):
        df.to_csv(r'C:\Users\mario\CSV de estudios\CryptoAPI.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\mario\CSV de estudios\CryptoAPI.csv', mode='a', header=False)
    #Then to read in the file: df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')

# If that didn't work try using the local host URL as shown in the video

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute

print(df)

exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#      10 print(df)
#      12 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\mario\CSV de estudios\CryptoAPI.csv')
df72

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10745
# 1    1027     Ethereum    ETH      ethereum              8261
# 2     825  Tether USDt   USDT        tether             71910
# 3    1839          BNB    BNB           bnb              2017
# 4    5426       Solana    SOL        solana               616
# 5      52          XRP    XRP           xrp              1206
# 6    3408         USDC   USDC      usd-coin             16235
# 7    2010      Cardano    ADA       cardano              1032
# 8    5805    Avalanche   AVAX     avalanche               640
# 9      74     Dogecoin   DOGE      dogecoin               875
# 10   1958         TRON    TRX          tron               903
# 11   6636     Polkadot    DOT  polkadot-new               666
# 12   1975    Chainlink   LINK     chainlink              1573
# 13  11419      Toncoin    TON       toncoin               189
# 14   3890      Polygon  MATIC       polygon              1246
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-07-13T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-08-19T00:00:00.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2021-08-26T13:40:22.000Z
# 14  2019-04-28T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 5   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 6   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [defi, smart-contracts, three-arrows-capital-p...    720000000.00000
# 9   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 10  [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 11  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 12  [platform, defi, oracles, smart-contracts, sub...   1000000000.00000
# 13  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 14  [pos, platform, enterprise-solutions, zero-kno...  10000000000.00000
#
#     circulating_supply       total_supply  infinite_supply  platform  \
# 0       19600900.00000     19600900.00000            False       NaN
# 1      120179738.31652    120179738.31652             True       NaN
# 2    95184775480.94475  98601637401.43510             True       NaN
# 3      149549272.09340    149549272.09340            False       NaN
# 4      432810764.20144    567396359.95292             True       NaN
# 5    54266821529.00000  99988013070.00000            False       NaN
# 6    25477455020.15854  25477455020.15854            False       NaN
# 7    35395152870.17300  36542697459.69000            False       NaN
# 8      366663473.34488    434696383.34488            False       NaN
# 9   142692036383.70523 142692036383.70523             True       NaN
# 10   88216138716.09991  88216195409.69763             True       NaN
# 11    1268568018.23215   1400828519.94050             True       NaN
# 12     568099970.45279   1000000000.00000            False       NaN
# 13    3456870260.47743   5101314329.38520             True       NaN
# 14    9570275853.63434  10000000000.00000            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                               NaN                       NaN
# 10        11                 71659659264.00000          7729182141.95930
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                  3414166606.00000          7822175207.72683
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2024-01-17T17:56:00.000Z      42373.81117     21542210255.79383
# 1       None  2024-01-17T17:56:00.000Z       2529.84822     11008912601.05015
# 2       None  2024-01-17T17:55:00.000Z          0.99928     40304114496.54163
# 3       None  2024-01-17T17:55:00.000Z        310.36412      1200372351.51705
# 4       None  2024-01-17T17:56:00.000Z         98.95689      2853545045.59902
# 5       None  2024-01-17T17:56:00.000Z          0.56654       877605245.11891
# 6       None  2024-01-17T17:56:00.000Z          1.00019      5254613139.68374
# 7       None  2024-01-17T17:55:00.000Z          0.52737       308320524.81394
# 8       None  2024-01-17T17:55:00.000Z         35.69318       537509572.28230
# 9       None  2024-01-17T17:56:00.000Z          0.08009       273737560.97629
# 10      None  2024-01-17T17:55:00.000Z          0.10786       221251261.73056
# 11      None  2024-01-17T17:55:00.000Z          7.32647       192254404.32302
# 12      None  2024-01-17T17:55:00.000Z         15.75916       757976905.49753
# 13      None  2024-01-17T17:56:00.000Z          2.29109        59056277.13297
# 14      None  2024-01-17T17:55:00.000Z          0.82437       334389210.26882
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                     -13.40000                      0.03814
# 1                       7.46600                     -0.07063
# 2                      -8.52490                      0.02859
# 3                      -2.93260                     -0.18220
# 4                      51.94610                      0.11652
# 5                      -9.34260                     -0.11334
# 6                       1.04580                      0.01508
# 7                      -5.55660                      0.17635
# 8                      13.21210                      0.41172
# 9                     -17.34810                     -0.01292
# 10                    -37.60630                     -0.02390
# 11                      0.75080                     -0.21678
# 12                     86.39580                     -0.91920
# 13                    -10.34390                     -0.17969
# 14                     11.67520                     -1.24867
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -1.55894                     -8.38673
# 1                       -1.39504                      3.89675
# 2                       -0.04054                     -0.12323
# 3                       -2.05899                      4.75844
# 4                        2.12746                      2.90638
# 5                       -1.93814                     -0.51839
# 6                        0.01241                     -0.03210
# 7                       -2.59131                      3.69311
# 8                        0.39404                      1.06079
# 9                       -1.39826                      2.06973
# 10                      -0.36520                      3.24924
# 11                      -1.79347                      2.79343
# 12                       4.63940                     11.36537
# 13                      -5.61571                      3.75650
# 14                      -2.43853                     -2.41336
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                        2.10564                      15.66239
# 1                       16.74762                      28.67687
# 2                       -0.03761                      -0.13353
# 3                       30.07781                      26.98124
# 4                       37.62379                      69.72921
# 5                       -5.70165                      -7.19764
# 6                       -0.00276                       0.01132
# 7                       -8.16962                      42.16103
# 8                      -10.06521                      61.61345
# 9                      -11.14488                      -0.14804
# 10                       7.98987                       4.93968
# 11                       9.60792                      39.28455
# 12                      10.61546                      15.36876
# 13                       9.42211                      -2.22568
# 14                       5.68915                       0.17788
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       48.37747    830564835268.82886
# 1                       61.95042    304036497010.90979
# 2                       -0.11746     95116104752.02605
# 3                       47.48680     46414727716.25370
# 4                      298.42131     42829608138.32184
# 5                       16.45099     30744563977.12706
# 6                        0.00963     25482356657.62146
# 7                      116.42911     18666420655.13709
# 8                      298.54975     13087385130.93839
# 9                       37.07421     11428251583.47909
# 10                      20.30114      9514957383.27662
# 11                     102.00423      9294125805.88615
# 12                     114.49450      8952779543.48839
# 13                       9.92152      7920013276.53860
# 14                      60.76365      7889427632.88125
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         49.66160                  889850034470.12000
# 1                         18.17910                  304036497010.90997
# 2                          5.68650                   98530501589.23000
# 3                          2.77530                   46414727716.25000
# 4                          2.56060                   56147780429.47000
# 5                          1.83830                   56654440247.06000
# 6                          1.52370                   25482356657.62000
# 7                          1.11600                   23731750292.54000
# 8                          0.78240                   25699089162.92000
# 9                          0.68330                   11428251583.48000
# 10                         0.56890                    9514963498.23000
# 11                         0.55570                   10263128432.75000
# 12                         0.53520                   15759162135.41000
# 13                         0.47350                   11687588533.03000
# 14                         0.47170                    8243678399.18000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-01-17T17:56:00.000Z          NaN           NaN
# 1           None  2024-01-17T17:56:00.000Z          NaN           NaN
# 2           None  2024-01-17T17:55:00.000Z   1027.00000      Ethereum
# 3           None  2024-01-17T17:55:00.000Z          NaN           NaN
# 4           None  2024-01-17T17:56:00.000Z          NaN           NaN
# 5           None  2024-01-17T17:56:00.000Z          NaN           NaN
# 6           None  2024-01-17T17:56:00.000Z   1027.00000      Ethereum
# 7           None  2024-01-17T17:55:00.000Z          NaN           NaN
# 8           None  2024-01-17T17:55:00.000Z          NaN           NaN
# 9           None  2024-01-17T17:56:00.000Z          NaN           NaN
# 10          None  2024-01-17T17:55:00.000Z          NaN           NaN
# 11          None  2024-01-17T17:55:00.000Z          NaN           NaN
# 12          None  2024-01-17T17:55:00.000Z   1027.00000      Ethereum
# 13          None  2024-01-17T17:56:00.000Z          NaN           NaN
# 14          None  2024-01-17T17:55:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2024-01-17 18:57:28.260428
# 1  2024-01-17 18:57:28.260428
# 2  2024-01-17 18:57:28.260428
# 3  2024-01-17 18:57:28.260428
# 4  2024-01-17 18:57:28.260428
# 5  2024-01-17 18:57:28.260428
# 6  2024-01-17 18:57:28.260428
# 7  2024-01-17 18:57:28.260428
# 8  2024-01-17 18:57:28.260428
# 9  2024-01-17 18:57:28.260428
# 10 2024-01-17 18:57:28.260428
# 11 2024-01-17 18:57:28.260428
# 12 2024-01-17 18:57:28.260428
# 13 2024-01-17 18:57:28.260428
# 14 2024-01-17 18:57:28.260428

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.03814                      -1.55894
# Ethereum                        -0.07063                      -1.39504
# Tether USDt                      0.02859                      -0.04054
# BNB                             -0.18220                      -2.05899
# Solana                           0.11652                       2.12746
# XRP                             -0.11334                      -1.93814
# USDC                             0.01508                       0.01241
# Cardano                          0.17635                      -2.59131
# Avalanche                        0.41172                       0.39404
# Dogecoin                        -0.01292                      -1.39826
# TRON                            -0.02390                      -0.36520
# Polkadot                        -0.21678                      -1.79347
# Chainlink                       -0.91920                       4.63940
# Toncoin                         -0.17969                      -5.61571
# Polygon                         -1.24867                      -2.43853
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                         -8.38673                       2.10564
# Ethereum                         3.89675                      16.74762
# Tether USDt                     -0.12323                      -0.03761
# BNB                              4.75844                      30.07781
# Solana                           2.90638                      37.62379
# XRP                             -0.51839                      -5.70165
# USDC                            -0.03210                      -0.00276
# Cardano                          3.69311                      -8.16962
# Avalanche                        1.06079                     -10.06521
# Dogecoin                         2.06973                     -11.14488
# TRON                             3.24924                       7.98987
# Polkadot                         2.79343                       9.60792
# Chainlink                       11.36537                      10.61546
# Toncoin                          3.75650                       9.42211
# Polygon                         -2.41336                       5.68915
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          15.66239                      48.37747
# Ethereum                         28.67687                      61.95042
# Tether USDt                      -0.13353                      -0.11746
# BNB                              26.98124                      47.48680
# Solana                           69.72921                     298.42131
# XRP                              -7.19764                      16.45099
# USDC                              0.01132                       0.00963
# Cardano                          42.16103                     116.42911
# Avalanche                        61.61345                     298.54975
# Dogecoin                         -0.14804                      37.07421
# TRON                              4.93968                      20.30114
# Polkadot                         39.28455                     102.00423
# Chainlink                        15.36876                     114.49450
# Toncoin                          -2.22568                       9.92152
# Polygon                           0.17788                      60.76365

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.03814
#              quote.USD.percent_change_24h    -1.55894
#              quote.USD.percent_change_7d     -8.38673
#              quote.USD.percent_change_30d     2.10564
#              quote.USD.percent_change_60d    15.66239
#              quote.USD.percent_change_90d    48.37747
# Ethereum     quote.USD.percent_change_1h     -0.07063
#              quote.USD.percent_change_24h    -1.39504
#              quote.USD.percent_change_7d      3.89675
#              quote.USD.percent_change_30d    16.74762
#              quote.USD.percent_change_60d    28.67687
#              quote.USD.percent_change_90d    61.95042
# Tether USDt  quote.USD.percent_change_1h      0.02859
#              quote.USD.percent_change_24h    -0.04054
#              quote.USD.percent_change_7d     -0.12323
#              quote.USD.percent_change_30d    -0.03761
#              quote.USD.percent_change_60d    -0.13353
#              quote.USD.percent_change_90d    -0.11746
# BNB          quote.USD.percent_change_1h     -0.18220
#              quote.USD.percent_change_24h    -2.05899
#              quote.USD.percent_change_7d      4.75844
#              quote.USD.percent_change_30d    30.07781
#              quote.USD.percent_change_60d    26.98124
#              quote.USD.percent_change_90d    47.48680
# Solana       quote.USD.percent_change_1h      0.11652
#              quote.USD.percent_change_24h     2.12746
#              quote.USD.percent_change_7d      2.90638
#              quote.USD.percent_change_30d    37.62379
#              quote.USD.percent_change_60d    69.72921
#              quote.USD.percent_change_90d   298.42131
# XRP          quote.USD.percent_change_1h     -0.11334
#              quote.USD.percent_change_24h    -1.93814
#              quote.USD.percent_change_7d     -0.51839
#              quote.USD.percent_change_30d    -5.70165
#              quote.USD.percent_change_60d    -7.19764
#              quote.USD.percent_change_90d    16.45099
# USDC         quote.USD.percent_change_1h      0.01508
#              quote.USD.percent_change_24h     0.01241
#              quote.USD.percent_change_7d     -0.03210
#              quote.USD.percent_change_30d    -0.00276
#              quote.USD.percent_change_60d     0.01132
#              quote.USD.percent_change_90d     0.00963
# Cardano      quote.USD.percent_change_1h      0.17635
#              quote.USD.percent_change_24h    -2.59131
#              quote.USD.percent_change_7d      3.69311
#              quote.USD.percent_change_30d    -8.16962
#              quote.USD.percent_change_60d    42.16103
#              quote.USD.percent_change_90d   116.42911
# Avalanche    quote.USD.percent_change_1h      0.41172
#              quote.USD.percent_change_24h     0.39404
#              quote.USD.percent_change_7d      1.06079
#              quote.USD.percent_change_30d   -10.06521
#              quote.USD.percent_change_60d    61.61345
#              quote.USD.percent_change_90d   298.54975
# Dogecoin     quote.USD.percent_change_1h     -0.01292
#              quote.USD.percent_change_24h    -1.39826
#              quote.USD.percent_change_7d      2.06973
#              quote.USD.percent_change_30d   -11.14488
#              quote.USD.percent_change_60d    -0.14804
#              quote.USD.percent_change_90d    37.07421
# TRON         quote.USD.percent_change_1h     -0.02390
#              quote.USD.percent_change_24h    -0.36520
#              quote.USD.percent_change_7d      3.24924
#              quote.USD.percent_change_30d     7.98987
#              quote.USD.percent_change_60d     4.93968
#              quote.USD.percent_change_90d    20.30114
# Polkadot     quote.USD.percent_change_1h     -0.21678
#              quote.USD.percent_change_24h    -1.79347
#              quote.USD.percent_change_7d      2.79343
#              quote.USD.percent_change_30d     9.60792
#              quote.USD.percent_change_60d    39.28455
#              quote.USD.percent_change_90d   102.00423
# Chainlink    quote.USD.percent_change_1h     -0.91920
#              quote.USD.percent_change_24h     4.63940
#              quote.USD.percent_change_7d     11.36537
#              quote.USD.percent_change_30d    10.61546
#              quote.USD.percent_change_60d    15.36876
#              quote.USD.percent_change_90d   114.49450
# Toncoin      quote.USD.percent_change_1h     -0.17969
#              quote.USD.percent_change_24h    -5.61571
#              quote.USD.percent_change_7d      3.75650
#              quote.USD.percent_change_30d     9.42211
#              quote.USD.percent_change_60d    -2.22568
#              quote.USD.percent_change_90d     9.92152
# Polygon      quote.USD.percent_change_1h     -1.24867
#              quote.USD.percent_change_24h    -2.43853
#              quote.USD.percent_change_7d     -2.41336
#              quote.USD.percent_change_30d     5.68915
#              quote.USD.percent_change_60d     0.17788
#              quote.USD.percent_change_90d    60.76365
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.03814
#             quote.USD.percent_change_24h  -1.55894
#             quote.USD.percent_change_7d   -8.38673
#             quote.USD.percent_change_30d   2.10564
#             quote.USD.percent_change_60d  15.66239
#             quote.USD.percent_change_90d  48.37747
# Ethereum    quote.USD.percent_change_1h   -0.07063
#             quote.USD.percent_change_24h  -1.39504
#             quote.USD.percent_change_7d    3.89675
#             quote.USD.percent_change_30d  16.74762
#             quote.USD.percent_change_60d  28.67687
#             quote.USD.percent_change_90d  61.95042
# Tether USDt quote.USD.percent_change_1h    0.02859
#             quote.USD.percent_change_24h  -0.04054
#             quote.USD.percent_change_7d   -0.12323
#             quote.USD.percent_change_30d  -0.03761
#             quote.USD.percent_change_60d  -0.13353
#             quote.USD.percent_change_90d  -0.11746
# BNB         quote.USD.percent_change_1h   -0.18220
#             quote.USD.percent_change_24h  -2.05899
#             quote.USD.percent_change_7d    4.75844
#             quote.USD.percent_change_30d  30.07781
#             quote.USD.percent_change_60d  26.98124
#             quote.USD.percent_change_90d  47.48680
# Solana      quote.USD.percent_change_1h    0.11652
#             quote.USD.percent_change_24h   2.12746
#             quote.USD.percent_change_7d    2.90638
#             quote.USD.percent_change_30d  37.62379
#             quote.USD.percent_change_60d  69.72921
#             quote.USD.percent_change_90d 298.42131
# XRP         quote.USD.percent_change_1h   -0.11334
#             quote.USD.percent_change_24h  -1.93814
#             quote.USD.percent_change_7d   -0.51839
#             quote.USD.percent_change_30d  -5.70165
#             quote.USD.percent_change_60d  -7.19764
#             quote.USD.percent_change_90d  16.45099
# USDC        quote.USD.percent_change_1h    0.01508
#             quote.USD.percent_change_24h   0.01241
#             quote.USD.percent_change_7d   -0.03210
#             quote.USD.percent_change_30d  -0.00276
#             quote.USD.percent_change_60d   0.01132
#             quote.USD.percent_change_90d   0.00963
# Cardano     quote.USD.percent_change_1h    0.17635
#             quote.USD.percent_change_24h  -2.59131
#             quote.USD.percent_change_7d    3.69311
#             quote.USD.percent_change_30d  -8.16962
#             quote.USD.percent_change_60d  42.16103
#             quote.USD.percent_change_90d 116.42911
# Avalanche   quote.USD.percent_change_1h    0.41172
#             quote.USD.percent_change_24h   0.39404
#             quote.USD.percent_change_7d    1.06079
#             quote.USD.percent_change_30d -10.06521
#             quote.USD.percent_change_60d  61.61345
#             quote.USD.percent_change_90d 298.54975
# Dogecoin    quote.USD.percent_change_1h   -0.01292
#             quote.USD.percent_change_24h  -1.39826
#             quote.USD.percent_change_7d    2.06973
#             quote.USD.percent_change_30d -11.14488
#             quote.USD.percent_change_60d  -0.14804
#             quote.USD.percent_change_90d  37.07421
# TRON        quote.USD.percent_change_1h   -0.02390
#             quote.USD.percent_change_24h  -0.36520
#             quote.USD.percent_change_7d    3.24924
#             quote.USD.percent_change_30d   7.98987
#             quote.USD.percent_change_60d   4.93968
#             quote.USD.percent_change_90d  20.30114
# Polkadot    quote.USD.percent_change_1h   -0.21678
#             quote.USD.percent_change_24h  -1.79347
#             quote.USD.percent_change_7d    2.79343
#             quote.USD.percent_change_30d   9.60792
#             quote.USD.percent_change_60d  39.28455
#             quote.USD.percent_change_90d 102.00423
# Chainlink   quote.USD.percent_change_1h   -0.91920
#             quote.USD.percent_change_24h   4.63940
#             quote.USD.percent_change_7d   11.36537
#             quote.USD.percent_change_30d  10.61546
#             quote.USD.percent_change_60d  15.36876
#             quote.USD.percent_change_90d 114.49450
# Toncoin     quote.USD.percent_change_1h   -0.17969
#             quote.USD.percent_change_24h  -5.61571
#             quote.USD.percent_change_7d    3.75650
#             quote.USD.percent_change_30d   9.42211
#             quote.USD.percent_change_60d  -2.22568
#             quote.USD.percent_change_90d   9.92152
# Polygon     quote.USD.percent_change_1h   -1.24867
#             quote.USD.percent_change_24h  -2.43853
#             quote.USD.percent_change_7d   -2.41336
#             quote.USD.percent_change_30d   5.68915
#             quote.USD.percent_change_60d   0.17788
#             quote.USD.percent_change_90d  60.76365

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.03814
# 1       Bitcoin  quote.USD.percent_change_24h  -1.55894
# 2       Bitcoin   quote.USD.percent_change_7d  -8.38673
# 3       Bitcoin  quote.USD.percent_change_30d   2.10564
# 4       Bitcoin  quote.USD.percent_change_60d  15.66239
# 5       Bitcoin  quote.USD.percent_change_90d  48.37747
# 6      Ethereum   quote.USD.percent_change_1h  -0.07063
# 7      Ethereum  quote.USD.percent_change_24h  -1.39504
# 8      Ethereum   quote.USD.percent_change_7d   3.89675
# 9      Ethereum  quote.USD.percent_change_30d  16.74762
# 10     Ethereum  quote.USD.percent_change_60d  28.67687
# 11     Ethereum  quote.USD.percent_change_90d  61.95042
# 12  Tether USDt   quote.USD.percent_change_1h   0.02859
# 13  Tether USDt  quote.USD.percent_change_24h  -0.04054
# 14  Tether USDt   quote.USD.percent_change_7d  -0.12323
# 15  Tether USDt  quote.USD.percent_change_30d  -0.03761
# 16  Tether USDt  quote.USD.percent_change_60d  -0.13353
# 17  Tether USDt  quote.USD.percent_change_90d  -0.11746
# 18          BNB   quote.USD.percent_change_1h  -0.18220
# 19          BNB  quote.USD.percent_change_24h  -2.05899
# 20          BNB   quote.USD.percent_change_7d   4.75844
# 21          BNB  quote.USD.percent_change_30d  30.07781
# 22          BNB  quote.USD.percent_change_60d  26.98124
# 23          BNB  quote.USD.percent_change_90d  47.48680
# 24       Solana   quote.USD.percent_change_1h   0.11652
# 25       Solana  quote.USD.percent_change_24h   2.12746
# 26       Solana   quote.USD.percent_change_7d   2.90638
# 27       Solana  quote.USD.percent_change_30d  37.62379
# 28       Solana  quote.USD.percent_change_60d  69.72921
# 29       Solana  quote.USD.percent_change_90d 298.42131
# 30          XRP   quote.USD.percent_change_1h  -0.11334
# 31          XRP  quote.USD.percent_change_24h  -1.93814
# 32          XRP   quote.USD.percent_change_7d  -0.51839
# 33          XRP  quote.USD.percent_change_30d  -5.70165
# 34          XRP  quote.USD.percent_change_60d  -7.19764
# 35          XRP  quote.USD.percent_change_90d  16.45099
# 36         USDC   quote.USD.percent_change_1h   0.01508
# 37         USDC  quote.USD.percent_change_24h   0.01241
# 38         USDC   quote.USD.percent_change_7d  -0.03210
# 39         USDC  quote.USD.percent_change_30d  -0.00276
# 40         USDC  quote.USD.percent_change_60d   0.01132
# 41         USDC  quote.USD.percent_change_90d   0.00963
# 42      Cardano   quote.USD.percent_change_1h   0.17635
# 43      Cardano  quote.USD.percent_change_24h  -2.59131
# 44      Cardano   quote.USD.percent_change_7d   3.69311
# 45      Cardano  quote.USD.percent_change_30d  -8.16962
# 46      Cardano  quote.USD.percent_change_60d  42.16103
# 47      Cardano  quote.USD.percent_change_90d 116.42911
# 48    Avalanche   quote.USD.percent_change_1h   0.41172
# 49    Avalanche  quote.USD.percent_change_24h   0.39404
# 50    Avalanche   quote.USD.percent_change_7d   1.06079
# 51    Avalanche  quote.USD.percent_change_30d -10.06521
# 52    Avalanche  quote.USD.percent_change_60d  61.61345
# 53    Avalanche  quote.USD.percent_change_90d 298.54975
# 54     Dogecoin   quote.USD.percent_change_1h  -0.01292
# 55     Dogecoin  quote.USD.percent_change_24h  -1.39826
# 56     Dogecoin   quote.USD.percent_change_7d   2.06973
# 57     Dogecoin  quote.USD.percent_change_30d -11.14488
# 58     Dogecoin  quote.USD.percent_change_60d  -0.14804
# 59     Dogecoin  quote.USD.percent_change_90d  37.07421
# 60         TRON   quote.USD.percent_change_1h  -0.02390
# 61         TRON  quote.USD.percent_change_24h  -0.36520
# 62         TRON   quote.USD.percent_change_7d   3.24924
# 63         TRON  quote.USD.percent_change_30d   7.98987
# 64         TRON  quote.USD.percent_change_60d   4.93968
# 65         TRON  quote.USD.percent_change_90d  20.30114
# 66     Polkadot   quote.USD.percent_change_1h  -0.21678
# 67     Polkadot  quote.USD.percent_change_24h  -1.79347
# 68     Polkadot   quote.USD.percent_change_7d   2.79343
# 69     Polkadot  quote.USD.percent_change_30d   9.60792
# 70     Polkadot  quote.USD.percent_change_60d  39.28455
# 71     Polkadot  quote.USD.percent_change_90d 102.00423
# 72    Chainlink   quote.USD.percent_change_1h  -0.91920
# 73    Chainlink  quote.USD.percent_change_24h   4.63940
# 74    Chainlink   quote.USD.percent_change_7d  11.36537
# 75    Chainlink  quote.USD.percent_change_30d  10.61546
# 76    Chainlink  quote.USD.percent_change_60d  15.36876
# 77    Chainlink  quote.USD.percent_change_90d 114.49450
# 78      Toncoin   quote.USD.percent_change_1h  -0.17969
# 79      Toncoin  quote.USD.percent_change_24h  -5.61571
# 80      Toncoin   quote.USD.percent_change_7d   3.75650
# 81      Toncoin  quote.USD.percent_change_30d   9.42211
# 82      Toncoin  quote.USD.percent_change_60d  -2.22568
# 83      Toncoin  quote.USD.percent_change_90d   9.92152
# 84      Polygon   quote.USD.percent_change_1h  -1.24867
# 85      Polygon  quote.USD.percent_change_24h  -2.43853
# 86      Polygon   quote.USD.percent_change_7d  -2.41336
# 87      Polygon  quote.USD.percent_change_30d   5.68915
# 88      Polygon  quote.USD.percent_change_60d   0.17788
# 89      Polygon  quote.USD.percent_change_90d  60.76365

# %%
# change column name 
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.03814
# 1       Bitcoin  quote.USD.percent_change_24h  -1.55894
# 2       Bitcoin   quote.USD.percent_change_7d  -8.38673
# 3       Bitcoin  quote.USD.percent_change_30d   2.10564
# 4       Bitcoin  quote.USD.percent_change_60d  15.66239
# 5       Bitcoin  quote.USD.percent_change_90d  48.37747
# 6      Ethereum   quote.USD.percent_change_1h  -0.07063
# 7      Ethereum  quote.USD.percent_change_24h  -1.39504
# 8      Ethereum   quote.USD.percent_change_7d   3.89675
# 9      Ethereum  quote.USD.percent_change_30d  16.74762
# 10     Ethereum  quote.USD.percent_change_60d  28.67687
# 11     Ethereum  quote.USD.percent_change_90d  61.95042
# 12  Tether USDt   quote.USD.percent_change_1h   0.02859
# 13  Tether USDt  quote.USD.percent_change_24h  -0.04054
# 14  Tether USDt   quote.USD.percent_change_7d  -0.12323
# 15  Tether USDt  quote.USD.percent_change_30d  -0.03761
# 16  Tether USDt  quote.USD.percent_change_60d  -0.13353
# 17  Tether USDt  quote.USD.percent_change_90d  -0.11746
# 18          BNB   quote.USD.percent_change_1h  -0.18220
# 19          BNB  quote.USD.percent_change_24h  -2.05899
# 20          BNB   quote.USD.percent_change_7d   4.75844
# 21          BNB  quote.USD.percent_change_30d  30.07781
# 22          BNB  quote.USD.percent_change_60d  26.98124
# 23          BNB  quote.USD.percent_change_90d  47.48680
# 24       Solana   quote.USD.percent_change_1h   0.11652
# 25       Solana  quote.USD.percent_change_24h   2.12746
# 26       Solana   quote.USD.percent_change_7d   2.90638
# 27       Solana  quote.USD.percent_change_30d  37.62379
# 28       Solana  quote.USD.percent_change_60d  69.72921
# 29       Solana  quote.USD.percent_change_90d 298.42131
# 30          XRP   quote.USD.percent_change_1h  -0.11334
# 31          XRP  quote.USD.percent_change_24h  -1.93814
# 32          XRP   quote.USD.percent_change_7d  -0.51839
# 33          XRP  quote.USD.percent_change_30d  -5.70165
# 34          XRP  quote.USD.percent_change_60d  -7.19764
# 35          XRP  quote.USD.percent_change_90d  16.45099
# 36         USDC   quote.USD.percent_change_1h   0.01508
# 37         USDC  quote.USD.percent_change_24h   0.01241
# 38         USDC   quote.USD.percent_change_7d  -0.03210
# 39         USDC  quote.USD.percent_change_30d  -0.00276
# 40         USDC  quote.USD.percent_change_60d   0.01132
# 41         USDC  quote.USD.percent_change_90d   0.00963
# 42      Cardano   quote.USD.percent_change_1h   0.17635
# 43      Cardano  quote.USD.percent_change_24h  -2.59131
# 44      Cardano   quote.USD.percent_change_7d   3.69311
# 45      Cardano  quote.USD.percent_change_30d  -8.16962
# 46      Cardano  quote.USD.percent_change_60d  42.16103
# 47      Cardano  quote.USD.percent_change_90d 116.42911
# 48    Avalanche   quote.USD.percent_change_1h   0.41172
# 49    Avalanche  quote.USD.percent_change_24h   0.39404
# 50    Avalanche   quote.USD.percent_change_7d   1.06079
# 51    Avalanche  quote.USD.percent_change_30d -10.06521
# 52    Avalanche  quote.USD.percent_change_60d  61.61345
# 53    Avalanche  quote.USD.percent_change_90d 298.54975
# 54     Dogecoin   quote.USD.percent_change_1h  -0.01292
# 55     Dogecoin  quote.USD.percent_change_24h  -1.39826
# 56     Dogecoin   quote.USD.percent_change_7d   2.06973
# 57     Dogecoin  quote.USD.percent_change_30d -11.14488
# 58     Dogecoin  quote.USD.percent_change_60d  -0.14804
# 59     Dogecoin  quote.USD.percent_change_90d  37.07421
# 60         TRON   quote.USD.percent_change_1h  -0.02390
# 61         TRON  quote.USD.percent_change_24h  -0.36520
# 62         TRON   quote.USD.percent_change_7d   3.24924
# 63         TRON  quote.USD.percent_change_30d   7.98987
# 64         TRON  quote.USD.percent_change_60d   4.93968
# 65         TRON  quote.USD.percent_change_90d  20.30114
# 66     Polkadot   quote.USD.percent_change_1h  -0.21678
# 67     Polkadot  quote.USD.percent_change_24h  -1.79347
# 68     Polkadot   quote.USD.percent_change_7d   2.79343
# 69     Polkadot  quote.USD.percent_change_30d   9.60792
# 70     Polkadot  quote.USD.percent_change_60d  39.28455
# 71     Polkadot  quote.USD.percent_change_90d 102.00423
# 72    Chainlink   quote.USD.percent_change_1h  -0.91920
# 73    Chainlink  quote.USD.percent_change_24h   4.63940
# 74    Chainlink   quote.USD.percent_change_7d  11.36537
# 75    Chainlink  quote.USD.percent_change_30d  10.61546
# 76    Chainlink  quote.USD.percent_change_60d  15.36876
# 77    Chainlink  quote.USD.percent_change_90d 114.49450
# 78      Toncoin   quote.USD.percent_change_1h  -0.17969
# 79      Toncoin  quote.USD.percent_change_24h  -5.61571
# 80      Toncoin   quote.USD.percent_change_7d   3.75650
# 81      Toncoin  quote.USD.percent_change_30d   9.42211
# 82      Toncoin  quote.USD.percent_change_60d  -2.22568
# 83      Toncoin  quote.USD.percent_change_90d   9.92152
# 84      Polygon   quote.USD.percent_change_1h  -1.24867
# 85      Polygon  quote.USD.percent_change_24h  -2.43853
# 86      Polygon   quote.USD.percent_change_7d  -2.41336
# 87      Polygon  quote.USD.percent_change_30d   5.68915
# 88      Polygon  quote.USD.percent_change_60d   0.17788
# 89      Polygon  quote.USD.percent_change_90d  60.76365

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   0.03814
# 1       Bitcoin            24h  -1.55894
# 2       Bitcoin             7d  -8.38673
# 3       Bitcoin            30d   2.10564
# 4       Bitcoin            60d  15.66239
# 5       Bitcoin            90d  48.37747
# 6      Ethereum             1h  -0.07063
# 7      Ethereum            24h  -1.39504
# 8      Ethereum             7d   3.89675
# 9      Ethereum            30d  16.74762
# 10     Ethereum            60d  28.67687
# 11     Ethereum            90d  61.95042
# 12  Tether USDt             1h   0.02859
# 13  Tether USDt            24h  -0.04054
# 14  Tether USDt             7d  -0.12323
# 15  Tether USDt            30d  -0.03761
# 16  Tether USDt            60d  -0.13353
# 17  Tether USDt            90d  -0.11746
# 18          BNB             1h  -0.18220
# 19          BNB            24h  -2.05899
# 20          BNB             7d   4.75844
# 21          BNB            30d  30.07781
# 22          BNB            60d  26.98124
# 23          BNB            90d  47.48680
# 24       Solana             1h   0.11652
# 25       Solana            24h   2.12746
# 26       Solana             7d   2.90638
# 27       Solana            30d  37.62379
# 28       Solana            60d  69.72921
# 29       Solana            90d 298.42131
# 30          XRP             1h  -0.11334
# 31          XRP            24h  -1.93814
# 32          XRP             7d  -0.51839
# 33          XRP            30d  -5.70165
# 34          XRP            60d  -7.19764
# 35          XRP            90d  16.45099
# 36         USDC             1h   0.01508
# 37         USDC            24h   0.01241
# 38         USDC             7d  -0.03210
# 39         USDC            30d  -0.00276
# 40         USDC            60d   0.01132
# 41         USDC            90d   0.00963
# 42      Cardano             1h   0.17635
# 43      Cardano            24h  -2.59131
# 44      Cardano             7d   3.69311
# 45      Cardano            30d  -8.16962
# 46      Cardano            60d  42.16103
# 47      Cardano            90d 116.42911
# 48    Avalanche             1h   0.41172
# 49    Avalanche            24h   0.39404
# 50    Avalanche             7d   1.06079
# 51    Avalanche            30d -10.06521
# 52    Avalanche            60d  61.61345
# 53    Avalanche            90d 298.54975
# 54     Dogecoin             1h  -0.01292
# 55     Dogecoin            24h  -1.39826
# 56     Dogecoin             7d   2.06973
# 57     Dogecoin            30d -11.14488
# 58     Dogecoin            60d  -0.14804
# 59     Dogecoin            90d  37.07421
# 60         TRON             1h  -0.02390
# 61         TRON            24h  -0.36520
# 62         TRON             7d   3.24924
# 63         TRON            30d   7.98987
# 64         TRON            60d   4.93968
# 65         TRON            90d  20.30114
# 66     Polkadot             1h  -0.21678
# 67     Polkadot            24h  -1.79347
# 68     Polkadot             7d   2.79343
# 69     Polkadot            30d   9.60792
# 70     Polkadot            60d  39.28455
# 71     Polkadot            90d 102.00423
# 72    Chainlink             1h  -0.91920
# 73    Chainlink            24h   4.63940
# 74    Chainlink             7d  11.36537
# 75    Chainlink            30d  10.61546
# 76    Chainlink            60d  15.36876
# 77    Chainlink            90d 114.49450
# 78      Toncoin             1h  -0.17969
# 79      Toncoin            24h  -5.61571
# 80      Toncoin             7d   3.75650
# 81      Toncoin            30d   9.42211
# 82      Toncoin            60d  -2.22568
# 83      Toncoin            90d   9.92152
# 84      Polygon             1h  -1.24867
# 85      Polygon            24h  -2.43853
# 86      Polygon             7d  -2.41336
# 87      Polygon            30d   5.68915
# 88      Polygon            60d   0.17788
# 89      Polygon            90d  60.76365

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
# Out:
# C:\Users\mario\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      42373.81117 2024-01-17 18:57:28.260428

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
